# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import urllib.request
import os

# %%
vocabs = []
folder_final = './videos'
last_page = 65 # adjust for testing on small batches

# %%
# get the link of a video page and the name of the vocabulary being shown
def get_entries_from_list(url):
    answer = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'})
    html = BeautifulSoup(answer.text, 'html.parser')

    # <a href="link" title="Vokabel">Vokabel</a>
    elements = [elem.div.a for elem in html.find_all('div', class_='record')]

    for elem in elements:
        d = {
            'title': elem.get('title'),
            'link': elem.get('href')
        }
        vocabs.append(d)

# %%
def cleanup_vocabs_titles():
    changed_titles = []

    # cleanup title extras and change / and : occurances
    for i in range(len(vocabs)):
        vocabs[i]['title'] = vocabs[i]['title'].replace('Details zu \'', '')
        vocabs[i]['title'] = vocabs[i]['title'].replace('\' anzeigen', '')
        vocabs[i]['title'] = vocabs[i]['title'].replace('/', '&sol;')
        vocabs[i]['title'] = vocabs[i]['title'].replace(':', '&colon;')
        vocabs[i]['title'] = vocabs[i]['title'].strip()

    # add _1 to title duplicates
    for i in range(len(vocabs)):
        if(i == 0):
            continue
        if(vocabs[i]['title'].lower() == vocabs[i - 1]['title'].lower()):
            vocabs[i]['title'] = vocabs[i]['title'] + "_1"
            changed_titles.append(vocabs[i]["title"])

    # print(changed_titles)

# %%
def get_video_data(url):
    answer = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'})
    html = BeautifulSoup(answer.text, 'html.parser')

    elements = [elem.source for elem in html.find_all('video')]
    video_urls = [elem.get('src') for elem in elements]

    labels = [elem.string for elem in html.find_all('td', class_='label')]
    values = [elem.string for elem in html.find_all('td', class_='value')]

    for i in range(len(labels)):
        labels[i] = labels[i].replace(u'\xa0', '')
        labels[i] = labels[i].replace(':', '')
        values[i] = values[i].replace(u'\xa0', '')
        values[i] = values[i].replace('\n', '')
        values[i] = values[i].replace('\t', '')
    
    meta = dict()
    
    for i, label in enumerate(labels):
        meta[label] = values[i]

    return video_urls, meta

# %%
def cleanup_edge_cases():

    # remove vocabs without videos
    for i, vocab in enumerate(vocabs):
        if(len(vocab['video_urls']) == 0):
            vocabs.pop(i)
    
    # very specific edge cases
    vocabs[532]['meta_data']['Name'] = vocabs[532]['meta_data']['Name'].replace(', \u03c72', '')
    vocabs[532]['title'] = vocabs[532]['title'].replace(', \u03c72', '')
    vocabs[1057]['meta_data']['Name'] = 'Fluidität'

# %%
# create folder vor vocabulary, fill it with metadata as a txt and all mp4s that belong to that vocab
def download_video_and_meta(vocab):
    folder_path = folder_final + f'/{vocab["title"]}'

    # create a folder
    os.mkdir(folder_path)

    folder_path_file = folder_path + f'/{vocab["title"]}'

    # write metadata in txt
    with open(folder_path_file + '.txt', 'w') as f:
        f.write(str(vocab['meta_data']))

    # download the video(s)
    if(len(vocab['video_urls']) == 0):
        return
    elif(len(vocab['video_urls']) == 1):
        url = vocab['video_urls'][0]
        filename = folder_path_file + '.mp4'
        urllib.request.urlretrieve(url, filename)
        return

    for i, video_url in enumerate(vocab['video_urls']):
        url = video_url
        filename = folder_path_file + f'_{chr(97 + i)}.mp4'
        urllib.request.urlretrieve(url, filename)

# %%
vocabs = []
last_page = 65

print('filling vocabs array with title & link...')
get_entries_from_list('https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/action/list/')
for i in tqdm(range(1, last_page, 1)):
    get_entries_from_list(f'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/action/list/page/{i}/')

print('\n cleaning up vocabs')
cleanup_vocabs_titles()

print('\n getting all mp4 urls and the metadata of each vocab')
for i in tqdm(range(len(vocabs))):
    vocabs[i]['video_urls'], vocabs[i]['meta_data'] = get_video_data(vocabs[i]['link'])

print('\n removing vocabs without video')
cleanup_edge_cases()

vocabs
# Out:
# filling vocabs array with title & link...
# 100%|██████████| 64/64 [00:40<00:00,  1.56it/s]
#  cleaning up vocabs
#
#  getting all mp4 urls and the metadata of each vocab
# 100%|██████████| 3234/3234 [22:31<00:00,  2.39it/s]
#  removing vocabs without video
# [{'title': 'Abbildungsverzeichnis',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abbildungsverzeichnis/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abbildungsverzeichnis_3.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abbildungsverzeichnis_4.mp4'],
#   'meta_data': {'Name': 'Abbildungsverzeichnis',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Abbruchbedingung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/phylogenetisch/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/phylogenetisch_2.mp4'],
#   'meta_data': {'Name': 'Abbruchbedingung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Abdichtung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abdichtung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abdichtung_1.mp4'],
#   'meta_data': {'Name': 'Abdichtung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abduktion',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abduktion/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abduktion_1.mp4'],
#   'meta_data': {'Name': 'Abduktion',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Aberglaube',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aberglaube/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aberglaube_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aberglaube_2.mp4'],
#   'meta_data': {'Name': 'Aberglaube',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Abfertigung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abfertigung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abfertigung_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abfertigung_2.mp4'],
#   'meta_data': {'Name': 'Abfertigung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Abfluss',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abfluss/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abfluss_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abfluss_2.mp4'],
#   'meta_data': {'Name': 'Abfluss',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abflussbeiwert',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abflussbeiwert/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abflussbeiwert_1.mp4'],
#   'meta_data': {'Name': 'Abflussbeiwert',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abgehängte Decke',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abgehaengte-decke/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abgehaengte-decke_1.mp4'],
#   'meta_data': {'Name': 'Abgehängte Decke',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abgrenzung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abgrenzung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abgrenzung_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abgrenzung_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abgrenzung_3.mp4'],
#   'meta_data': {'Name': 'Abgrenzung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Allgemeine wissenschaftliche Begriffe'}},
#  {'title': 'Abhandlung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abhandlung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abhandlung_2.mp4'],
#   'meta_data': {'Name': 'Abhandlung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Allgemeine wissenschaftliche Begriffe'}},
#  {'title': 'Ablation',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ablation/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ablation_2.mp4'],
#   'meta_data': {'Name': 'Ablation',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Ablation_1',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ablation-1/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ablation_3.mp4'],
#   'meta_data': {'Name': 'Ablation',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Ablaufdiagramm',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/anis/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/anis_2.mp4'],
#   'meta_data': {'Name': 'Ablaufdiagramm',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Ablauforganisation',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ablauforganisation/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ablauforganisation_1.mp4'],
#   'meta_data': {'Name': 'Ablauforganisation',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Wirtschaftsinformatik'}},
#  {'title': 'ablehnender Bescheid',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ablehnender-bescheid/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ablehnender-bescheid_3.mp4'],
#   'meta_data': {'Name': 'ablehnender Bescheid',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Ableitung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ableitung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abhandlung_1.mp4'],
#   'meta_data': {'Name': 'Ableitung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Allgemeine wissenschaftliche Begriffe'}},
#  {'title': 'Abnahme',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abnahme/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abnahme_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abnahme_2.mp4'],
#   'meta_data': {'Name': 'Abnahme',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abnormität',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absentismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absentismus_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absentismus_2.mp4'],
#   'meta_data': {'Name': 'Abnormität',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Abrechnung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abrechnung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abrechnung_1.mp4'],
#   'meta_data': {'Name': 'Abrechnung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Absatz',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absatz/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absatz_1.mp4'],
#   'meta_data': {'Name': 'Absatz',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'Abschreibung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abschreibung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abschreibung_1.mp4'],
#   'meta_data': {'Name': 'Abschreibung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'Absenz',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absenz/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absenz_1.mp4'],
#   'meta_data': {'Name': 'Absenz',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'absolut, absolute Häufigkeit',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absolut/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absolut_1.mp4'],
#   'meta_data': {'Name': 'absolut, absolute Häufigkeit',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'absoluter Bezug',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absoluter-bzug/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absoluter-bzug_1.mp4'],
#   'meta_data': {'Name': 'absoluter Bezug',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Absolutismus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absolutismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absolutismus_1.mp4'],
#   'meta_data': {'Name': 'Absolutismus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Geschichte'}},
#  {'title': 'Absorption',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absorption/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absorption_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absorption_1.mp4'],
#   'meta_data': {'Name': 'Absorption',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Abstellraum',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abstellraum/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abstellraum_1.mp4'],
#   'meta_data': {'Name': 'Abstellraum',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abstract',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abstract/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abstract_1.mp4'],
#   'meta_data': {'Name': 'Abstract',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Allgemeine wissenschaftliche Begriffe'}},
#  {'title': 'abstrakt',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abstrakt/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abstrakt_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abstrakt_3.mp4'],
#   'meta_data': {'Name': 'abstrakt',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'abstrakte Malerei',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abstrakte-malerei/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abstrakte-malerei_1.mp4'],
#   'meta_data': {'Name': 'abstrakte Malerei',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Abstraktion',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abstraktion/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abstraktion_1.mp4'],
#   'meta_data': {'Name': 'Abstraktion',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Abstraktionshierachie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/besorgungszettel/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/besorgungszettel_3.mp4'],
#   'meta_data': {'Name': 'Abstraktionshierachie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Abteilung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abteilung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abteilung_1.mp4'],
#   'meta_data': {'Name': 'Abteilung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abteilungsleiter',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abteilungsleiter/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abteilungsleiter_1.mp4'],
#   'meta_data': {'Name': 'Abteilungsleiter',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abulie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abulie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abulie_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abulie_beschreibung_1.mp4'],
#   'meta_data': {'Name': 'Abulie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'abwärtskompatibel',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abwaertskompatibel/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abwaertskompatibel_1.mp4'],
#   'meta_data': {'Name': 'abwärtskompatibel',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'abweichendes Verhalten (Devianz, Delinquenz)',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abweichendes-verhalten/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abweichendes-verhalten_1.mp4'],
#   'meta_data': {'Name': 'abweichendes Verhalten (Devianz, Delinquenz)',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Abwertung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abwertung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abwertung_1.mp4'],
#   'meta_data': {'Name': 'Abwertung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': ''}},
#  {'title': 'Abzinsungsfaktor',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abzinsungsfaktor/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abzinsungsfaktor_1.mp4'],
#   'meta_data': {'Name': 'Abzinsungsfaktor',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'Abzug',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abzuege/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abzuege_1.mp4'],
#   'meta_data': {'Name': 'Abzug',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Access',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/access/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/access_1.mp4'],
#   'meta_data': {'Name': 'Access',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Accessibility',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/accessibility/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/accessibility_1.mp4'],
#   'meta_data': {'Name': 'Accessibility',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Accesskey',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/accesskey/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/accesskey_1.mp4'],
#   'meta_data': {'Name': 'Accesskey',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Acetylierung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/acethylisierung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/acethylisierung_1.mp4'],
#   'meta_data': {'Name': 'Acetylierung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Achsen',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/achsen/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/achsen_1.mp4'],
#   'meta_data': {'Name': 'Achsen',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Achtsamkeit',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/achtsamkeit/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/achtsamkeit_1.mp4'],
#   'meta_data': {'Name': 'Achtsamkeit',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'Ackerschachtelhalm',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ackerschachtelhalm-lat-equisetum-arvense/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ackerschachtelhalm-lat-equisetum-arvense-_2.mp4'],
#   'meta_data': {'Name': 'Ackerschachtelhalm',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Botanik'}},
#  {'title': 'Action Painting',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/action-painting/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/action-painting_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/action-painting_2.mp4'],
#   'meta_data': {'Name': 'Action Painting',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'ActionScript',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/actionscript/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/actionscript_1.mp4'],
#   'meta_data': {'Name': 'ActionScript',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Adaptierung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adaptierung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adaptierung_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adaptierung_2.mp4'],
#   'meta_data': {'Name': 'Adaptierung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Adaptivität',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adaptivitt/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adaptivitt-_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adaptivitt-_3.mp4'],
#   'meta_data': {'Name': 'Adaptivität ',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Adäquat',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adquat/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adquat_1.mp4'],
#   'meta_data': {'Name': 'Adäquat',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'AddIn',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/addin/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/addin_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/addin_2.mp4'],
#   'meta_data': {'Name': 'AddIn',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Additum',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/additum/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/additum_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/additum_2.mp4'],
#   'meta_data': {'Name': 'Additum',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'AddOn',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/addon/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/addon_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/addon_2.mp4'],
#   'meta_data': {'Name': 'AddOn',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'ADHS &sol; ADS',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adhs/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adhs_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adhs_2.mp4'],
#   'meta_data': {'Name': 'ADHS / ADS',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Adipokine',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adipokine/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adipokine_1.mp4'],
#   'meta_data': {'Name': 'Adipokine',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Adipositas',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adipositas/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adipositas-_1.mp4'],
#   'meta_data': {'Name': 'Adipositas ',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Adipozyten',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adipozyten/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adipozyten_1.mp4'],
#   'meta_data': {'Name': 'Adipozyten',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Adjektiv',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adjektiv/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adjektiv_1.mp4'],
#   'meta_data': {'Name': 'Adjektiv',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'Adoleszenz',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adoleszenz/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adoleszenz_1.mp4'],
#   'meta_data': {'Name': 'Adoleszenz',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Adrenalin',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adrenalin/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adrenalin_1.mp4'],
#   'meta_data': {'Name': 'Adrenalin',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Adressspeicherung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adressspeicherung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adressspeicherung_1.mp4'],
#   'meta_data': {'Name': 'Adressspeicherung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Adsorber',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adsorber/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adsorber_3.mp4'],
#   'meta_data': {'Name': 'Adsorber',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Aerob',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aerob/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aerob_2.mp4'],
#   'meta_data': {'Name': 'Aerob',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'Aerobic',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aerobic/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aerobic_1.mp4'],
#   'meta_data': {'Name': 'Aerobic',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'Aerophagie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aerophagie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aerophagie-_1.mp4'],
#   'meta_data': {'Name': 'Aerophagie ',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Affäre',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/affaere/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affaere_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affaere_3.mp4'],
#   'meta_data': {'Name': 'Affäre',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Geschichte'}},
#  {'title': 'Affekt',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/affekt/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affekt_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affekt_2.mp4'],
#   'meta_data': {'Name': 'Affekt',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'affektuelles Handeln, affektives Handeln',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/affektuelles-handeln/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affektuelles-handeln_1.mp4'],
#   'meta_data': {'Name': 'affektuelles Handeln, affektives Handeln',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Afferent',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/afferent/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/afferent_1.mp4'],
#   'meta_data': {'Name': 'Afferent',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Affinität',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/affinitaet/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affinitaet_1.mp4'],
#   'meta_data': {'Name': 'Affinität',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Affirmation',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/affirmation/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affirmation_1.mp4'],
#   'meta_data': {'Name': 'Affirmation',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Affix',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/affix/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affix_2.mp4'],
#   'meta_data': {'Name': 'Affix',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'Agentenfilm',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/agentenfilm/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agentenfilm_1.mp4'],
#   'meta_data': {'Name': 'Agentenfilm',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Aggregation, Aggregat',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aggregation3769/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aggregation_2.mp4'],
#   'meta_data': {'Name': 'Aggregation, Aggregat',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Aggregationsebene',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aggregationsebene/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aggregationsebene_1.mp4'],
#   'meta_data': {'Name': 'Aggregationsebene',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'aggregiert',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aggregiert/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aggregiert_1.mp4'],
#   'meta_data': {'Name': 'aggregiert',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Agio',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/agio/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agio_1.mp4'],
#   'meta_data': {'Name': 'Agio',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'Agnosie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/agnosie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agnosie_1.mp4'],
#   'meta_data': {'Name': 'Agnosie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Agonist',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/agonist/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agonist_1.mp4'],
#   'meta_data': {'Name': 'Agonist',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'Agoraphobie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/agoraphobie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agoraphobie_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agoraphobie_2.mp4'],
#   'meta_data': {'Name': 'Agoraphobie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'Agrammatismus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/agrammatismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agrammatismus_1.mp4'],
#   'meta_data': {'Name': 'Agrammatismus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Akinese',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akinese/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akinese_1.mp4'],
#   'meta_data': {'Name': 'Akinese',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Akkordarbeit',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akkordarbeit/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akkordarbeit_1.mp4'],
#   'meta_data': {'Name': 'Akkordarbeit',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Akkumulation',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akkumulation/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akkumulation_1.mp4'],
#   'meta_data': {'Name': 'Akkumulation',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Akkusativ',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akkusativ/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akkusativ_3.mp4'],
#   'meta_data': {'Name': 'Akkusativ',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'Akt (Kunst)',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akt-kunst/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akt-kunst_1.mp4'],
#   'meta_data': {'Name': 'Akt (Kunst)',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Akt (Literatur)',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akt/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akt_1.mp4'],
#   'meta_data': {'Name': 'Akt (Literatur)',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Akteur',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akteur/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akteur_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akteur_2.mp4'],
#   'meta_data': {'Name': 'Akteur',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft,Wirtschaftsinformatik'}},
#  {'title': 'Aktiva-Passiva',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aktiva-passiva/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktiva-passiva_1.mp4'],
#   'meta_data': {'Name': 'Aktiva-Passiva',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'Aktivator',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aktivator/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktivator_1.mp4'],
#   'meta_data': {'Name': 'Aktivator',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Aktivitätsdiagramm',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aktivitaetsdiagramm/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktivitaetsdiagramm_1.mp4'],
#   'meta_data': {'Name': 'Aktivitätsdiagramm',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'Aktmalerei',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aktmalerei/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktmalerei_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktmalerei_2.mp4'],
#   'meta_data': {'Name': 'Aktmalerei',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Aktzeichnung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aktzeichnung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktzeichnung_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktzeichnung_2.mp4'],
#   'meta_data': {'Name': 'Aktzeichnung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'akustische Halluzination',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akustische-halluzination/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akustische-halluzination_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akustische-halluzination_2.mp4'],
#   'meta_data': {'Name': 'akustische Halluzination',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'akut',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akut/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akut_1.mp4'],
#   'meta_data': {'Name': 'akut',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Akzeleration',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akzeleration/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akzeleration_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akzeleration_2.mp4'],
#   'meta_data': {'Name': 'Akzeleration',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'akzentuieren',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ethos/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ethos_1.mp4'],
#   'meta_data': {'Name': 'akzentuieren',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Alant',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alant-inula-helenium-l/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alant-inula-helenium-l_1.mp4'],
#   'meta_data': {'Name': 'Alant',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Botanik'}},
#  {'title': 'Albertina',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/albertina/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/albertina_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/albertina_2.mp4'],
#   'meta_data': {'Name': 'Albertina',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Albrecht Dürer',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/albrecht-duerer/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/albrecht-duerer_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/albrecht-duerer_2.mp4'],
#   'meta_data': {'Name': 'Albrecht Dürer',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Alchemie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alchemie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alchemie_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alchemie_3.mp4'],
#   'meta_data': {'Name': 'Alchemie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Alchemist',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alchemist/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alchemist_1.mp4'],
#   'meta_data': {'Name': 'Alchemist',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Alexa',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alexa/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alexa_2.mp4'],
#   'meta_data': {'Name': 'Alexa',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Alexej Svetlov',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alexej-svetlov/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alexej-svetlov_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alexej-svetlov_2.mp4'],
#   'meta_data': {'Name': 'Alexej Svetlov',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Algorithmus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/algorithmus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/algorithmus_1.mp4'],
#   'meta_data': {'Name': 'Algorithmus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Alignment',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alignment/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alignment_2.mp4'],
#   'meta_data': {'Name': 'Alignment',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Alimente',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alimente/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alimente_1.mp4'],
#   'meta_data': {'Name': 'Alimente',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Alkohol',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alkohol/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alkohol_1.mp4'],
#   'meta_data': {'Name': 'Alkohol',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'Allegorie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allegorie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allegorie_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allegorie_2.mp4'],
#   'meta_data': {'Name': 'Allegorie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Allel',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allel/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allel_1.mp4'],
#   'meta_data': {'Name': 'Allel',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Allergen',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allergen/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allergen_1.mp4'],
#   'meta_data': {'Name': 'Allergen',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Allergie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allergie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allergie_1.mp4'],
#   'meta_data': {'Name': 'Allergie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Allgemeine Literaturwissenschaft',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allgemeine-literaturwissenschaft/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allgemeine-literaturwissenschaft_2.mp4'],
#   'meta_data': {'Name': 'Allgemeine Literaturwissenschaft',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Alliteration',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alliteration/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alliteration_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alliteration_3.mp4'],
#   'meta_data': {'Name': 'Alliteration',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'allogen',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allogen/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allogen_1.mp4'],
#   'meta_data': {'Name': 'allogen',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Allomorphe',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allomorphe/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allomorphe_2.mp4'],
#   'meta_data': {'Name': 'Allomorphe',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'Alloreaktiv',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alloreaktiv/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alloreaktiv_1.mp4'],
#   'meta_data': {'Name': 'Alloreaktiv',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Aloe Vera',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aloe-vera/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aloe-vera_1.mp4'],
#   'meta_data': {'Name': 'Aloe Vera',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Botanik'}},
#  {'title': 'Alpha',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alpha/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alpha_1.mp4'],
#   'meta_data': {'Name': 'Alpha',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'alt-Attribut',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alt-attribut/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alt-attribut_1.mp4'],
#   'meta_data': {'Name': 'alt-Attribut',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'alt-Text',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alt-text/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alt-text_1.mp4'],
#   'meta_data': {'Name': 'alt-Text',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'alternativ',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alternativ/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alternativ_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alternativ_2.mp4'],
#   'meta_data': {'Name': 'alternativ',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Alternativhypothese',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alternativhypothese/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alternativhypothese_1.mp4'],
#   'meta_data': {'Name': 'Alternativhypothese',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Altertum',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/altertum/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/altertum_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/altertum_2.mp4'],
#   'meta_data': {'Name': 'Altertum',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Alu',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alu/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alu_1.mp4'],
#   'meta_data': {'Name': 'Alu',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'ALU (Arithmetic and Logic Unit) &sol; Rechenwerk',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alu-arithmetic-and-logic-unit-rechenwerk/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alu-arithmetic-and-logic-unit--rechenwerk_1.mp4'],
#   'meta_data': {'Name': 'ALU (Arithmetic and Logic Unit) / Rechenwerk',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Alzheimer',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alzheimer/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alzheimer_1.mp4'],
#   'meta_data': {'Name': 'Alzheimer',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'Amateur',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amateur/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amateur_1.mp4'],
#   'meta_data': {'Name': 'Amateur',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Amateurfilm',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amateurfilm/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amateurfilm_1.mp4'],
#   'meta_data': {'Name': 'Amateurfilm',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Amazon',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amazon/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amazon_1.mp4'],
#   'meta_data': {'Name': 'Amazon',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Amazone',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amazone/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amazone_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amazone_3.mp4'],
#   'meta_data': {'Name': 'Amazone',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'ambig',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ambig/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ambig_1.mp4'],
#   'meta_data': {'Name': 'ambig',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'Ambivalenz, ambivalent',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ambivalent/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ambivalent_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ambivalent_2.mp4'],
#   'meta_data': {'Name': 'Ambivalenz, ambivalent',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'ambulant',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ambulant/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ambulant_1.mp4'],
#   'meta_data': {'Name': 'ambulant',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Aminosäure',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aminosaeure/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aminosaeure_2.mp4'],
#   'meta_data': {'Name': 'Aminosäure',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Amöbe',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amoebe/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amoebe_2.mp4'],
#   'meta_data': {'Name': 'Amöbe',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Amphiphil',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amphiphil/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amphiphil_1.mp4'],
#   'meta_data': {'Name': 'Amphiphil',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Amplifikation',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amplifikation/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amplifikation_1.mp4'],
#   'meta_data': {'Name': 'Amplifikation',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Ampulle',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ampulle/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ampulle_1.mp4'],
#   'meta_data': {'Name': 'Ampulle',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Anaerob',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/anaerob/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/anaerob_2.mp4'],
#   'meta_data': {'Name': 'Anaerob',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'Analgetikum',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/analgetikum/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/analgetikum_1.mp4'],
#   'meta_data': {'Name': 'Analgetikum',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Analyse',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/analyse/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/analyse_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/analyse_3.mp4'],
#   'meta_data': {'Name': 'Analyse',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Literaturwissenschaft,Soziologie'}},
#  {'title': 'Anamnese',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/anamnese/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/anamnese_1.mp4'],
#   'meta_data': {'Name': 'Anamnese',
#    'Herkunft': 'Neue Gebärde',
# ...
#  {'title': 'explorative Datenanalyse',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/explorative-datenanalyse/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/explorative-datenanalyse_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/explorative-datenanalyse_2.mp4'],
#   'meta_data': {'Name': 'explorative Datenanalyse',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'explorative Funktion',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/explorative-funktion/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/explorative-funktion_1.mp4'],
#   'meta_data': {'Name': 'explorative Funktion',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Explorer',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/explorer/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/explorer_1.mp4'],
#   'meta_data': {'Name': 'Explorer',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Exponent',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/exponent/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/exponent_2.mp4'],
#   'meta_data': {'Name': 'Exponent',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Mathematik'}},
#  {'title': 'exponentiell',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/exponentiell/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/exponentiell_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/exponentiell_2.mp4'],
#   'meta_data': {'Name': 'exponentiell',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Exposé',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/expose/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/expose_2.mp4'],
#   'meta_data': {'Name': 'Exposé',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Expression',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/expression-1/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/expression_2.mp4'],
#   'meta_data': {'Name': 'Expression',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Expressionismus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/expressionismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/expressionismus_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/expressionismus_2.mp4'],
#   'meta_data': {'Name': 'Expressionismus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst,Literaturwissenschaft'}},
#  {'title': 'expressiv',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/expressiv/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/expressiv_2.mp4'],
#   'meta_data': {'Name': 'expressiv',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'expressive Funktion',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/expressive-funktion/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/expressive-funktion_1.mp4'],
#   'meta_data': {'Name': 'expressive Funktion',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Extension',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/extension/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/extension_1.mp4'],
#   'meta_data': {'Name': 'Extension',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'extensiv',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/extensiv/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/extensiv_1.mp4'],
#   'meta_data': {'Name': 'extensiv',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Extrakt',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/extrakt/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/extrakt_1.mp4'],
#   'meta_data': {'Name': 'Extrakt',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Extraversion',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/extraversion/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/extraversion_1.mp4'],
#   'meta_data': {'Name': 'Extraversion',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'Extremum',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/extremum/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/extremum_2.mp4'],
#   'meta_data': {'Name': 'Extremum',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Mathematik'}},
#  {'title': 'extrinsisch',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/extrinsisch/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/extrinsisch_1.mp4'],
#   'meta_data': {'Name': 'extrinsisch',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'exzentrisch',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/exzentrisch/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/exzentrisch_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/exzentrisch_2.mp4'],
#   'meta_data': {'Name': 'exzentrisch',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'Exzision',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/exzision/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/exzision_1.mp4'],
#   'meta_data': {'Name': 'Exzision',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Fabel',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fabel/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fabel_1.mp4'],
#   'meta_data': {'Name': 'Fabel',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Fachwerk',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fachwerk/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fachwerk_1.mp4'],
#   'meta_data': {'Name': 'Fachwerk',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Facility Management (=Lebenszyklusanalyse)',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/facility-management-lebenszyklusanalyse/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/facility-management-lebenszyklusanalyse_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/facility-management-lebenszyklusanalyse_2.mp4'],
#   'meta_data': {'Name': 'Facility Management (=Lebenszyklusanalyse)',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'FACS (Fluoreszenaktivierter Zellsortierer)',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/facs/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/facs_1.mp4'],
#   'meta_data': {'Name': 'FACS (Fluoreszenaktivierter Zellsortierer)',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Fagott',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fagott/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fagott_1.mp4'],
#   'meta_data': {'Name': 'Fagott',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Fahrlässigkeit',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fahrlaessigkeit/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fahrlaessigkeit_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fahrlaessigkeit_2.mp4'],
#   'meta_data': {'Name': 'Fahrlässigkeit',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Rechtswissenschaften'}},
#  {'title': 'Faksimile',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faksimile/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faksimile_1.mp4'],
#   'meta_data': {'Name': 'Faksimile',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Faktizität &sol; Faktum, Tatbestand',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faktizitaet/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faktizitaet_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faktizitaet_2.mp4'],
#   'meta_data': {'Name': 'Faktizität / Faktum, Tatbestand',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Faktoren',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faktoren/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faktoren_2.mp4'],
#   'meta_data': {'Name': 'Faktoren',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Psychologie,Soziologie'}},
#  {'title': 'Fakultaticprotokoll',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fakultaticprotokoll/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fakultaticprotokoll_1.mp4'],
#   'meta_data': {'Name': 'Fakultaticprotokoll',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Fälschung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faelschung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faelschung_1.mp4'],
#   'meta_data': {'Name': 'Fälschung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Falsum',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/falsum/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/falsum_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/falsum_2.mp4'],
#   'meta_data': {'Name': 'Falsum',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Faltmatte',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faltmatte/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faltmatte_2.mp4'],
#   'meta_data': {'Name': 'Faltmatte',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'Familiäre Hypercholesterinämie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/familiaere-hypercholesterinaemie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/familiaere-hypercholesterinaemie_2.mp4'],
#   'meta_data': {'Name': 'Familiäre Hypercholesterinämie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'fangen',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fangen/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fangen_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fangen_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fangen_3.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fangen_4.mp4'],
#   'meta_data': {'Name': 'fangen',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'färben',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faerben/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faerben_1.mp4'],
#   'meta_data': {'Name': 'färben',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Farbenkreis',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/farbenkreis/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/farbenkreis_1.mp4'],
#   'meta_data': {'Name': 'Farbenkreis',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Farbentiefe',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/farbentiefe/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/farbentiefe_1.mp4'],
#   'meta_data': {'Name': 'Farbentiefe',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Farbpalette',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/farbpalette/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/farbpalette_2.mp4'],
#   'meta_data': {'Name': 'Farbpalette',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Farbschema',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/farbschema/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/farbschema_2.mp4'],
#   'meta_data': {'Name': 'Farbschema',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Faschismus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faschismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faschismus_1.mp4'],
#   'meta_data': {'Name': 'Faschismus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Geschichte'}},
#  {'title': 'Faserzement',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faserzement/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faserzement_1.mp4'],
#   'meta_data': {'Name': 'Faserzement',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Fassade',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fassade/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fassade_1.mp4'],
#   'meta_data': {'Name': 'Fassade',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Fasten',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fasten/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fasten_1.mp4'],
#   'meta_data': {'Name': 'Fasten',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Fauvismus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fauvismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fauvismus_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fauvismus_2.mp4'],
#   'meta_data': {'Name': 'Fauvismus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Favicon',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/favicon/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/favicon_1.mp4'],
#   'meta_data': {'Name': 'Favicon',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'fehlende Triade',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fehlende-triade/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fehlende-triade_1.mp4'],
#   'meta_data': {'Name': 'fehlende Triade',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'Feldforschung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/feldforschung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/feldforschung_1.mp4'],
#   'meta_data': {'Name': 'Feldforschung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Allgemeine wissenschaftliche Begriffe'}},
#  {'title': 'Feminisierung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/feminisierung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/feminisierung_1.mp4'],
#   'meta_data': {'Name': 'Feminisierung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Feminismus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/feminismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/feminismus_1.mp4'],
#   'meta_data': {'Name': 'Feminismus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Geschichte,Literaturwissenschaft'}},
#  ...]

# %%
folder_final = './videos'
for vocab in tqdm(vocabs):
    download_video_and_meta(vocab)

vocabs
# Out:
# 100%|██████████| 3214/3214 [31:50<00:00,  1.68it/s]
# [{'title': 'Abbildungsverzeichnis',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abbildungsverzeichnis/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abbildungsverzeichnis_3.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abbildungsverzeichnis_4.mp4'],
#   'meta_data': {'Name': 'Abbildungsverzeichnis',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Abbruchbedingung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/phylogenetisch/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/phylogenetisch_2.mp4'],
#   'meta_data': {'Name': 'Abbruchbedingung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Abdichtung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abdichtung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abdichtung_1.mp4'],
#   'meta_data': {'Name': 'Abdichtung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abduktion',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abduktion/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abduktion_1.mp4'],
#   'meta_data': {'Name': 'Abduktion',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Aberglaube',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aberglaube/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aberglaube_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aberglaube_2.mp4'],
#   'meta_data': {'Name': 'Aberglaube',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Abfertigung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abfertigung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abfertigung_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abfertigung_2.mp4'],
#   'meta_data': {'Name': 'Abfertigung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Abfluss',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abfluss/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abfluss_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abfluss_2.mp4'],
#   'meta_data': {'Name': 'Abfluss',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abflussbeiwert',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abflussbeiwert/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abflussbeiwert_1.mp4'],
#   'meta_data': {'Name': 'Abflussbeiwert',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abgehängte Decke',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abgehaengte-decke/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abgehaengte-decke_1.mp4'],
#   'meta_data': {'Name': 'Abgehängte Decke',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abgrenzung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abgrenzung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abgrenzung_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abgrenzung_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abgrenzung_3.mp4'],
#   'meta_data': {'Name': 'Abgrenzung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Allgemeine wissenschaftliche Begriffe'}},
#  {'title': 'Abhandlung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abhandlung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abhandlung_2.mp4'],
#   'meta_data': {'Name': 'Abhandlung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Allgemeine wissenschaftliche Begriffe'}},
#  {'title': 'Ablation',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ablation/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ablation_2.mp4'],
#   'meta_data': {'Name': 'Ablation',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Ablation_1',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ablation-1/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ablation_3.mp4'],
#   'meta_data': {'Name': 'Ablation',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Ablaufdiagramm',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/anis/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/anis_2.mp4'],
#   'meta_data': {'Name': 'Ablaufdiagramm',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Ablauforganisation',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ablauforganisation/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ablauforganisation_1.mp4'],
#   'meta_data': {'Name': 'Ablauforganisation',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Wirtschaftsinformatik'}},
#  {'title': 'ablehnender Bescheid',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ablehnender-bescheid/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ablehnender-bescheid_3.mp4'],
#   'meta_data': {'Name': 'ablehnender Bescheid',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Ableitung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ableitung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abhandlung_1.mp4'],
#   'meta_data': {'Name': 'Ableitung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Allgemeine wissenschaftliche Begriffe'}},
#  {'title': 'Abnahme',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abnahme/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abnahme_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abnahme_2.mp4'],
#   'meta_data': {'Name': 'Abnahme',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abnormität',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absentismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absentismus_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absentismus_2.mp4'],
#   'meta_data': {'Name': 'Abnormität',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Abrechnung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abrechnung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abrechnung_1.mp4'],
#   'meta_data': {'Name': 'Abrechnung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Absatz',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absatz/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absatz_1.mp4'],
#   'meta_data': {'Name': 'Absatz',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'Abschreibung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abschreibung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abschreibung_1.mp4'],
#   'meta_data': {'Name': 'Abschreibung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'Absenz',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absenz/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absenz_1.mp4'],
#   'meta_data': {'Name': 'Absenz',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'absolut, absolute Häufigkeit',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absolut/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absolut_1.mp4'],
#   'meta_data': {'Name': 'absolut, absolute Häufigkeit',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'absoluter Bezug',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absoluter-bzug/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absoluter-bzug_1.mp4'],
#   'meta_data': {'Name': 'absoluter Bezug',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Absolutismus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absolutismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absolutismus_1.mp4'],
#   'meta_data': {'Name': 'Absolutismus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Geschichte'}},
#  {'title': 'Absorption',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/absorption/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absorption_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/absorption_1.mp4'],
#   'meta_data': {'Name': 'Absorption',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Abstellraum',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abstellraum/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abstellraum_1.mp4'],
#   'meta_data': {'Name': 'Abstellraum',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abstract',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abstract/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abstract_1.mp4'],
#   'meta_data': {'Name': 'Abstract',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Allgemeine wissenschaftliche Begriffe'}},
#  {'title': 'abstrakt',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abstrakt/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abstrakt_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abstrakt_3.mp4'],
#   'meta_data': {'Name': 'abstrakt',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'abstrakte Malerei',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abstrakte-malerei/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abstrakte-malerei_1.mp4'],
#   'meta_data': {'Name': 'abstrakte Malerei',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Abstraktion',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abstraktion/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abstraktion_1.mp4'],
#   'meta_data': {'Name': 'Abstraktion',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Abstraktionshierachie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/besorgungszettel/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/besorgungszettel_3.mp4'],
#   'meta_data': {'Name': 'Abstraktionshierachie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Abteilung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abteilung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abteilung_1.mp4'],
#   'meta_data': {'Name': 'Abteilung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abteilungsleiter',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abteilungsleiter/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abteilungsleiter_1.mp4'],
#   'meta_data': {'Name': 'Abteilungsleiter',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Abulie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abulie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abulie_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abulie_beschreibung_1.mp4'],
#   'meta_data': {'Name': 'Abulie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'abwärtskompatibel',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abwaertskompatibel/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abwaertskompatibel_1.mp4'],
#   'meta_data': {'Name': 'abwärtskompatibel',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'abweichendes Verhalten (Devianz, Delinquenz)',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abweichendes-verhalten/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abweichendes-verhalten_1.mp4'],
#   'meta_data': {'Name': 'abweichendes Verhalten (Devianz, Delinquenz)',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Abwertung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abwertung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abwertung_1.mp4'],
#   'meta_data': {'Name': 'Abwertung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': ''}},
#  {'title': 'Abzinsungsfaktor',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abzinsungsfaktor/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abzinsungsfaktor_1.mp4'],
#   'meta_data': {'Name': 'Abzinsungsfaktor',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'Abzug',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/abzuege/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/abzuege_1.mp4'],
#   'meta_data': {'Name': 'Abzug',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Access',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/access/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/access_1.mp4'],
#   'meta_data': {'Name': 'Access',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Accessibility',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/accessibility/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/accessibility_1.mp4'],
#   'meta_data': {'Name': 'Accessibility',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Accesskey',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/accesskey/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/accesskey_1.mp4'],
#   'meta_data': {'Name': 'Accesskey',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Acetylierung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/acethylisierung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/acethylisierung_1.mp4'],
#   'meta_data': {'Name': 'Acetylierung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Achsen',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/achsen/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/achsen_1.mp4'],
#   'meta_data': {'Name': 'Achsen',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Achtsamkeit',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/achtsamkeit/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/achtsamkeit_1.mp4'],
#   'meta_data': {'Name': 'Achtsamkeit',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'Ackerschachtelhalm',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ackerschachtelhalm-lat-equisetum-arvense/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ackerschachtelhalm-lat-equisetum-arvense-_2.mp4'],
#   'meta_data': {'Name': 'Ackerschachtelhalm',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Botanik'}},
#  {'title': 'Action Painting',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/action-painting/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/action-painting_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/action-painting_2.mp4'],
#   'meta_data': {'Name': 'Action Painting',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'ActionScript',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/actionscript/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/actionscript_1.mp4'],
#   'meta_data': {'Name': 'ActionScript',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Adaptierung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adaptierung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adaptierung_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adaptierung_2.mp4'],
#   'meta_data': {'Name': 'Adaptierung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Adaptivität',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adaptivitt/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adaptivitt-_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adaptivitt-_3.mp4'],
#   'meta_data': {'Name': 'Adaptivität ',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Adäquat',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adquat/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adquat_1.mp4'],
#   'meta_data': {'Name': 'Adäquat',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'AddIn',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/addin/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/addin_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/addin_2.mp4'],
#   'meta_data': {'Name': 'AddIn',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Additum',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/additum/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/additum_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/additum_2.mp4'],
#   'meta_data': {'Name': 'Additum',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'AddOn',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/addon/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/addon_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/addon_2.mp4'],
#   'meta_data': {'Name': 'AddOn',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'ADHS &sol; ADS',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adhs/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adhs_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adhs_2.mp4'],
#   'meta_data': {'Name': 'ADHS / ADS',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Adipokine',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adipokine/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adipokine_1.mp4'],
#   'meta_data': {'Name': 'Adipokine',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Adipositas',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adipositas/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adipositas-_1.mp4'],
#   'meta_data': {'Name': 'Adipositas ',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Adipozyten',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adipozyten/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adipozyten_1.mp4'],
#   'meta_data': {'Name': 'Adipozyten',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Adjektiv',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adjektiv/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adjektiv_1.mp4'],
#   'meta_data': {'Name': 'Adjektiv',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'Adoleszenz',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adoleszenz/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adoleszenz_1.mp4'],
#   'meta_data': {'Name': 'Adoleszenz',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Adrenalin',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adrenalin/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adrenalin_1.mp4'],
#   'meta_data': {'Name': 'Adrenalin',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Adressspeicherung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adressspeicherung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adressspeicherung_1.mp4'],
#   'meta_data': {'Name': 'Adressspeicherung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Adsorber',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/adsorber/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/adsorber_3.mp4'],
#   'meta_data': {'Name': 'Adsorber',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Aerob',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aerob/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aerob_2.mp4'],
#   'meta_data': {'Name': 'Aerob',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'Aerobic',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aerobic/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aerobic_1.mp4'],
#   'meta_data': {'Name': 'Aerobic',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'Aerophagie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aerophagie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aerophagie-_1.mp4'],
#   'meta_data': {'Name': 'Aerophagie ',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Affäre',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/affaere/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affaere_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affaere_3.mp4'],
#   'meta_data': {'Name': 'Affäre',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Geschichte'}},
#  {'title': 'Affekt',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/affekt/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affekt_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affekt_2.mp4'],
#   'meta_data': {'Name': 'Affekt',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'affektuelles Handeln, affektives Handeln',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/affektuelles-handeln/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affektuelles-handeln_1.mp4'],
#   'meta_data': {'Name': 'affektuelles Handeln, affektives Handeln',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Afferent',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/afferent/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/afferent_1.mp4'],
#   'meta_data': {'Name': 'Afferent',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Affinität',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/affinitaet/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affinitaet_1.mp4'],
#   'meta_data': {'Name': 'Affinität',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Affirmation',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/affirmation/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affirmation_1.mp4'],
#   'meta_data': {'Name': 'Affirmation',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Affix',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/affix/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/affix_2.mp4'],
#   'meta_data': {'Name': 'Affix',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'Agentenfilm',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/agentenfilm/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agentenfilm_1.mp4'],
#   'meta_data': {'Name': 'Agentenfilm',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Aggregation, Aggregat',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aggregation3769/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aggregation_2.mp4'],
#   'meta_data': {'Name': 'Aggregation, Aggregat',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Aggregationsebene',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aggregationsebene/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aggregationsebene_1.mp4'],
#   'meta_data': {'Name': 'Aggregationsebene',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'aggregiert',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aggregiert/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aggregiert_1.mp4'],
#   'meta_data': {'Name': 'aggregiert',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Agio',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/agio/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agio_1.mp4'],
#   'meta_data': {'Name': 'Agio',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'Agnosie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/agnosie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agnosie_1.mp4'],
#   'meta_data': {'Name': 'Agnosie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Agonist',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/agonist/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agonist_1.mp4'],
#   'meta_data': {'Name': 'Agonist',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'Agoraphobie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/agoraphobie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agoraphobie_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agoraphobie_2.mp4'],
#   'meta_data': {'Name': 'Agoraphobie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'Agrammatismus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/agrammatismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/agrammatismus_1.mp4'],
#   'meta_data': {'Name': 'Agrammatismus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Akinese',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akinese/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akinese_1.mp4'],
#   'meta_data': {'Name': 'Akinese',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Akkordarbeit',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akkordarbeit/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akkordarbeit_1.mp4'],
#   'meta_data': {'Name': 'Akkordarbeit',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Akkumulation',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akkumulation/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akkumulation_1.mp4'],
#   'meta_data': {'Name': 'Akkumulation',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Akkusativ',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akkusativ/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akkusativ_3.mp4'],
#   'meta_data': {'Name': 'Akkusativ',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'Akt (Kunst)',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akt-kunst/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akt-kunst_1.mp4'],
#   'meta_data': {'Name': 'Akt (Kunst)',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Akt (Literatur)',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akt/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akt_1.mp4'],
#   'meta_data': {'Name': 'Akt (Literatur)',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Akteur',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akteur/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akteur_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akteur_2.mp4'],
#   'meta_data': {'Name': 'Akteur',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft,Wirtschaftsinformatik'}},
#  {'title': 'Aktiva-Passiva',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aktiva-passiva/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktiva-passiva_1.mp4'],
#   'meta_data': {'Name': 'Aktiva-Passiva',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'Aktivator',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aktivator/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktivator_1.mp4'],
#   'meta_data': {'Name': 'Aktivator',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Aktivitätsdiagramm',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aktivitaetsdiagramm/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktivitaetsdiagramm_1.mp4'],
#   'meta_data': {'Name': 'Aktivitätsdiagramm',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'Aktmalerei',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aktmalerei/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktmalerei_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktmalerei_2.mp4'],
#   'meta_data': {'Name': 'Aktmalerei',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Aktzeichnung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aktzeichnung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktzeichnung_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aktzeichnung_2.mp4'],
#   'meta_data': {'Name': 'Aktzeichnung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'akustische Halluzination',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akustische-halluzination/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akustische-halluzination_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akustische-halluzination_2.mp4'],
#   'meta_data': {'Name': 'akustische Halluzination',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'akut',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akut/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akut_1.mp4'],
#   'meta_data': {'Name': 'akut',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Akzeleration',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/akzeleration/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akzeleration_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/akzeleration_2.mp4'],
#   'meta_data': {'Name': 'Akzeleration',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'akzentuieren',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ethos/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ethos_1.mp4'],
#   'meta_data': {'Name': 'akzentuieren',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Alant',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alant-inula-helenium-l/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alant-inula-helenium-l_1.mp4'],
#   'meta_data': {'Name': 'Alant',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Botanik'}},
#  {'title': 'Albertina',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/albertina/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/albertina_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/albertina_2.mp4'],
#   'meta_data': {'Name': 'Albertina',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Albrecht Dürer',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/albrecht-duerer/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/albrecht-duerer_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/albrecht-duerer_2.mp4'],
#   'meta_data': {'Name': 'Albrecht Dürer',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Alchemie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alchemie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alchemie_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alchemie_3.mp4'],
#   'meta_data': {'Name': 'Alchemie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Alchemist',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alchemist/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alchemist_1.mp4'],
#   'meta_data': {'Name': 'Alchemist',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Alexa',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alexa/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alexa_2.mp4'],
#   'meta_data': {'Name': 'Alexa',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Alexej Svetlov',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alexej-svetlov/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alexej-svetlov_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alexej-svetlov_2.mp4'],
#   'meta_data': {'Name': 'Alexej Svetlov',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Algorithmus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/algorithmus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/algorithmus_1.mp4'],
#   'meta_data': {'Name': 'Algorithmus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Alignment',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alignment/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alignment_2.mp4'],
#   'meta_data': {'Name': 'Alignment',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Alimente',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alimente/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alimente_1.mp4'],
#   'meta_data': {'Name': 'Alimente',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Alkohol',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alkohol/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alkohol_1.mp4'],
#   'meta_data': {'Name': 'Alkohol',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'Allegorie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allegorie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allegorie_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allegorie_2.mp4'],
#   'meta_data': {'Name': 'Allegorie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Allel',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allel/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allel_1.mp4'],
#   'meta_data': {'Name': 'Allel',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Allergen',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allergen/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allergen_1.mp4'],
#   'meta_data': {'Name': 'Allergen',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Allergie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allergie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allergie_1.mp4'],
#   'meta_data': {'Name': 'Allergie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Allgemeine Literaturwissenschaft',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allgemeine-literaturwissenschaft/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allgemeine-literaturwissenschaft_2.mp4'],
#   'meta_data': {'Name': 'Allgemeine Literaturwissenschaft',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Alliteration',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alliteration/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alliteration_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alliteration_3.mp4'],
#   'meta_data': {'Name': 'Alliteration',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'allogen',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allogen/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allogen_1.mp4'],
#   'meta_data': {'Name': 'allogen',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Allomorphe',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/allomorphe/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/allomorphe_2.mp4'],
#   'meta_data': {'Name': 'Allomorphe',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'Alloreaktiv',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alloreaktiv/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alloreaktiv_1.mp4'],
#   'meta_data': {'Name': 'Alloreaktiv',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Aloe Vera',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aloe-vera/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aloe-vera_1.mp4'],
#   'meta_data': {'Name': 'Aloe Vera',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Botanik'}},
#  {'title': 'Alpha',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alpha/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alpha_1.mp4'],
#   'meta_data': {'Name': 'Alpha',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'alt-Attribut',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alt-attribut/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alt-attribut_1.mp4'],
#   'meta_data': {'Name': 'alt-Attribut',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'alt-Text',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alt-text/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alt-text_1.mp4'],
#   'meta_data': {'Name': 'alt-Text',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'alternativ',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alternativ/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alternativ_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alternativ_2.mp4'],
#   'meta_data': {'Name': 'alternativ',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Alternativhypothese',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alternativhypothese/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alternativhypothese_1.mp4'],
#   'meta_data': {'Name': 'Alternativhypothese',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Altertum',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/altertum/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/altertum_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/altertum_2.mp4'],
#   'meta_data': {'Name': 'Altertum',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Alu',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alu/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alu_1.mp4'],
#   'meta_data': {'Name': 'Alu',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'ALU (Arithmetic and Logic Unit) &sol; Rechenwerk',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alu-arithmetic-and-logic-unit-rechenwerk/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alu-arithmetic-and-logic-unit--rechenwerk_1.mp4'],
#   'meta_data': {'Name': 'ALU (Arithmetic and Logic Unit) / Rechenwerk',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Alzheimer',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/alzheimer/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/alzheimer_1.mp4'],
#   'meta_data': {'Name': 'Alzheimer',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'Amateur',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amateur/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amateur_1.mp4'],
#   'meta_data': {'Name': 'Amateur',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Amateurfilm',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amateurfilm/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amateurfilm_1.mp4'],
#   'meta_data': {'Name': 'Amateurfilm',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Amazon',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amazon/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amazon_1.mp4'],
#   'meta_data': {'Name': 'Amazon',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Amazone',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amazone/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amazone_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amazone_3.mp4'],
#   'meta_data': {'Name': 'Amazone',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'ambig',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ambig/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ambig_1.mp4'],
#   'meta_data': {'Name': 'ambig',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'Ambivalenz, ambivalent',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ambivalent/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ambivalent_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ambivalent_2.mp4'],
#   'meta_data': {'Name': 'Ambivalenz, ambivalent',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'ambulant',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ambulant/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ambulant_1.mp4'],
#   'meta_data': {'Name': 'ambulant',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Aminosäure',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/aminosaeure/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/aminosaeure_2.mp4'],
#   'meta_data': {'Name': 'Aminosäure',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Amöbe',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amoebe/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amoebe_2.mp4'],
#   'meta_data': {'Name': 'Amöbe',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Amphiphil',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amphiphil/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amphiphil_1.mp4'],
#   'meta_data': {'Name': 'Amphiphil',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Amplifikation',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/amplifikation/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/amplifikation_1.mp4'],
#   'meta_data': {'Name': 'Amplifikation',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Ampulle',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ampulle/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ampulle_1.mp4'],
#   'meta_data': {'Name': 'Ampulle',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Anaerob',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/anaerob/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/anaerob_2.mp4'],
#   'meta_data': {'Name': 'Anaerob',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'Analgetikum',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/analgetikum/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/analgetikum_1.mp4'],
#   'meta_data': {'Name': 'Analgetikum',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Medizin'}},
#  {'title': 'Analyse',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/analyse/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/analyse_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/analyse_3.mp4'],
#   'meta_data': {'Name': 'Analyse',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Literaturwissenschaft,Soziologie'}},
#  {'title': 'Anamnese',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/anamnese/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/anamnese_1.mp4'],
#   'meta_data': {'Name': 'Anamnese',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sozialarbeit'}},
#  {'title': 'Ananas',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/ananas/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/ananas-_1.mp4',
# ...
#  {'title': 'explorative Datenanalyse',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/explorative-datenanalyse/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/explorative-datenanalyse_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/explorative-datenanalyse_2.mp4'],
#   'meta_data': {'Name': 'explorative Datenanalyse',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'explorative Funktion',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/explorative-funktion/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/explorative-funktion_1.mp4'],
#   'meta_data': {'Name': 'explorative Funktion',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Explorer',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/explorer/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/explorer_1.mp4'],
#   'meta_data': {'Name': 'Explorer',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Exponent',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/exponent/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/exponent_2.mp4'],
#   'meta_data': {'Name': 'Exponent',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Mathematik'}},
#  {'title': 'exponentiell',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/exponentiell/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/exponentiell_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/exponentiell_2.mp4'],
#   'meta_data': {'Name': 'exponentiell',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Exposé',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/expose/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/expose_2.mp4'],
#   'meta_data': {'Name': 'Exposé',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Expression',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/expression-1/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/expression_2.mp4'],
#   'meta_data': {'Name': 'Expression',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Expressionismus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/expressionismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/expressionismus_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/expressionismus_2.mp4'],
#   'meta_data': {'Name': 'Expressionismus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst,Literaturwissenschaft'}},
#  {'title': 'expressiv',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/expressiv/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/expressiv_2.mp4'],
#   'meta_data': {'Name': 'expressiv',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Linguistik'}},
#  {'title': 'expressive Funktion',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/expressive-funktion/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/expressive-funktion_1.mp4'],
#   'meta_data': {'Name': 'expressive Funktion',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Extension',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/extension/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/extension_1.mp4'],
#   'meta_data': {'Name': 'Extension',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'extensiv',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/extensiv/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/extensiv_1.mp4'],
#   'meta_data': {'Name': 'extensiv',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Extrakt',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/extrakt/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/extrakt_1.mp4'],
#   'meta_data': {'Name': 'Extrakt',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Extraversion',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/extraversion/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/extraversion_1.mp4'],
#   'meta_data': {'Name': 'Extraversion',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'Extremum',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/extremum/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/extremum_2.mp4'],
#   'meta_data': {'Name': 'Extremum',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Mathematik'}},
#  {'title': 'extrinsisch',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/extrinsisch/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/extrinsisch_1.mp4'],
#   'meta_data': {'Name': 'extrinsisch',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Wirtschaftswissenschaft'}},
#  {'title': 'exzentrisch',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/exzentrisch/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/exzentrisch_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/exzentrisch_2.mp4'],
#   'meta_data': {'Name': 'exzentrisch',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'Exzision',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/exzision/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/exzision_1.mp4'],
#   'meta_data': {'Name': 'Exzision',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Fabel',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fabel/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fabel_1.mp4'],
#   'meta_data': {'Name': 'Fabel',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Fachwerk',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fachwerk/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fachwerk_1.mp4'],
#   'meta_data': {'Name': 'Fachwerk',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Facility Management (=Lebenszyklusanalyse)',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/facility-management-lebenszyklusanalyse/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/facility-management-lebenszyklusanalyse_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/facility-management-lebenszyklusanalyse_2.mp4'],
#   'meta_data': {'Name': 'Facility Management (=Lebenszyklusanalyse)',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'FACS (Fluoreszenaktivierter Zellsortierer)',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/facs/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/facs_1.mp4'],
#   'meta_data': {'Name': 'FACS (Fluoreszenaktivierter Zellsortierer)',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Fagott',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fagott/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fagott_1.mp4'],
#   'meta_data': {'Name': 'Fagott',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Fahrlässigkeit',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fahrlaessigkeit/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fahrlaessigkeit_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fahrlaessigkeit_2.mp4'],
#   'meta_data': {'Name': 'Fahrlässigkeit',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Rechtswissenschaften'}},
#  {'title': 'Faksimile',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faksimile/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faksimile_1.mp4'],
#   'meta_data': {'Name': 'Faksimile',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Faktizität &sol; Faktum, Tatbestand',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faktizitaet/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faktizitaet_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faktizitaet_2.mp4'],
#   'meta_data': {'Name': 'Faktizität / Faktum, Tatbestand',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Faktoren',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faktoren/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faktoren_2.mp4'],
#   'meta_data': {'Name': 'Faktoren',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Psychologie,Soziologie'}},
#  {'title': 'Fakultaticprotokoll',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fakultaticprotokoll/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fakultaticprotokoll_1.mp4'],
#   'meta_data': {'Name': 'Fakultaticprotokoll',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Pädagogik'}},
#  {'title': 'Fälschung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faelschung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faelschung_1.mp4'],
#   'meta_data': {'Name': 'Fälschung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Falsum',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/falsum/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/falsum_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/falsum_2.mp4'],
#   'meta_data': {'Name': 'Falsum',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Soziologie'}},
#  {'title': 'Faltmatte',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faltmatte/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faltmatte_2.mp4'],
#   'meta_data': {'Name': 'Faltmatte',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'Familiäre Hypercholesterinämie',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/familiaere-hypercholesterinaemie/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/familiaere-hypercholesterinaemie_2.mp4'],
#   'meta_data': {'Name': 'Familiäre Hypercholesterinämie',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'fangen',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fangen/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fangen_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fangen_2.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fangen_3.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fangen_4.mp4'],
#   'meta_data': {'Name': 'fangen',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Sportwissenschaft'}},
#  {'title': 'färben',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faerben/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faerben_1.mp4'],
#   'meta_data': {'Name': 'färben',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Farbenkreis',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/farbenkreis/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/farbenkreis_1.mp4'],
#   'meta_data': {'Name': 'Farbenkreis',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Farbentiefe',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/farbentiefe/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/farbentiefe_1.mp4'],
#   'meta_data': {'Name': 'Farbentiefe',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Farbpalette',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/farbpalette/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/farbpalette_2.mp4'],
#   'meta_data': {'Name': 'Farbpalette',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Farbschema',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/farbschema/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/farbschema_2.mp4'],
#   'meta_data': {'Name': 'Farbschema',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'Faschismus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faschismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faschismus_1.mp4'],
#   'meta_data': {'Name': 'Faschismus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Geschichte'}},
#  {'title': 'Faserzement',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/faserzement/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/faserzement_1.mp4'],
#   'meta_data': {'Name': 'Faserzement',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Fassade',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fassade/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fassade_1.mp4'],
#   'meta_data': {'Name': 'Fassade',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Architektur'}},
#  {'title': 'Fasten',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fasten/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fasten_1.mp4'],
#   'meta_data': {'Name': 'Fasten',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Biologie,Molekularbiologie'}},
#  {'title': 'Fauvismus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fauvismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fauvismus_1.mp4',
#    'https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fauvismus_2.mp4'],
#   'meta_data': {'Name': 'Fauvismus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Kunst'}},
#  {'title': 'Favicon',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/favicon/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/favicon_1.mp4'],
#   'meta_data': {'Name': 'Favicon',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Informatik'}},
#  {'title': 'fehlende Triade',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/fehlende-triade/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/fehlende-triade_1.mp4'],
#   'meta_data': {'Name': 'fehlende Triade',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Psychologie'}},
#  {'title': 'Feldforschung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/feldforschung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/feldforschung_1.mp4'],
#   'meta_data': {'Name': 'Feldforschung',
#    'Herkunft': 'Existierende Gebärde',
#    'Themengebiete': 'Allgemeine wissenschaftliche Begriffe'}},
#  {'title': 'Feminisierung',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/feminisierung/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/feminisierung_1.mp4'],
#   'meta_data': {'Name': 'Feminisierung',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Literaturwissenschaft'}},
#  {'title': 'Feminismus',
#   'link': 'https://fachgebaerden.tsc.tuwien.ac.at/gebaerden/feminismus/',
#   'video_urls': ['https://fachgebaerden.tsc.tuwien.ac.at/fileadmin/videos/feminismus_1.mp4'],
#   'meta_data': {'Name': 'Feminismus',
#    'Herkunft': 'Neue Gebärde',
#    'Themengebiete': 'Geschichte,Literaturwissenschaft'}},
#  ...]
